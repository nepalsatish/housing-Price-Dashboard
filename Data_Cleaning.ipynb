# %%
import pandas as pd

# %%
df = pd.read_csv('/var/www/project/Housing/zhvi_data.csv')

# %%
df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  124341.456204
# 1    394913         1     New York, NY        msa        NY  222144.732358
# 2    753899         2  Los Angeles, CA        msa        CA  227474.670293
# 3    394463         3      Chicago, IL        msa        IL  157959.146515
# 4    394514         4       Dallas, TX        msa        TX  130592.692029
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  124560.212686  124831.502934  125413.367265  126083.023349  ...
# 1  223088.722133  224041.454953  225972.060310  227971.269013  ...
# 2  228321.164684  229448.687139  231692.078064  234145.644428  ...
# 3  158105.370670  158383.857148  159076.662297  159910.023559  ...
# 4  130650.858471  130717.726749  130891.376645  131120.329279  ...
#
#       2024-08-31     2024-09-30     2024-10-31     2024-11-30     2024-12-31  \
# ...

# %%
id_cols = ['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName']
df_long = pd.melt(df, id_vars=id_cols, var_name='Date', value_name='Price')
df_long['Date'] = pd.to_datetime(df_long['Date'])
df_long = df_long.dropna(subset=['Price'])
df_long.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName       Date  \
# 0    102001         0    United States    country       NaN 2000-01-31
# 1    394913         1     New York, NY        msa        NY 2000-01-31
# 2    753899         2  Los Angeles, CA        msa        CA 2000-01-31
# 3    394463         3      Chicago, IL        msa        IL 2000-01-31
# 4    394514         4       Dallas, TX        msa        TX 2000-01-31
#
#            Price
# 0  124341.456204
# 1  222144.732358
# 2  227474.670293
# 3  157959.146515
# 4  130592.692029

# %%
# Remove state initials from RegionName column
df_long['RegionName'] = df_long['RegionName'].str.split(',').str[0]

# Save the cleaned data
df_long.to_csv('/var/www/project/Housing/zhvi_data_long.csv', index=False)
print("Data cleaned and saved successfully!")
print(f"Shape of cleaned data: {df_long.shape}")
# Out:
# Data cleaned and saved successfully!
# Shape of cleaned data: (223709, 7)

# %%
test_cities = ['New York', 'Los Angeles', 'Chicago', 'Dallas', 'San Francisco']
df_test = df_long[df_long['RegionName'].isin(test_cities)]
df_test.to_csv('/var/www/project/Housing/zhvi_data_test.csv', index=False)
df_test.head()
# Out:
#     RegionID  SizeRank     RegionName RegionType StateName       Date  \
# 1     394913         1       New York        msa        NY 2000-01-31
# 2     753899         2    Los Angeles        msa        CA 2000-01-31
# 3     394463         3        Chicago        msa        IL 2000-01-31
# 4     394514         4         Dallas        msa        TX 2000-01-31
# 12    395057        12  San Francisco        msa        CA 2000-01-31
#
#             Price
# 1   222144.732358
# 2   227474.670293
# 3   157959.146515
# 4   130592.692029
# 12  297966.096390
